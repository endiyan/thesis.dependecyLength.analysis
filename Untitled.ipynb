# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/endiyan/Downloads/titanic.csv")

# %%
def multipliers (): 
    return [lambda x: i * x for i in range (4)]

# %% [raw]
# print([m (2) for m in multipliers ()])

# %%
df = pd.read_csv("out/5-12-22shuffle100_out.csv")

# %%
pd.set_option('display.max_rows', 500)
df.loc[:,["doc_id","token_length","token_id", "head_token_id","dependency_length","sum_dependency_length","new_token_id","prev_head_token_id","new_head_token_id", "new_dependency_length", "new_sum_dependency_length"]].head(200)
# Out:
#         doc_id  token_length  token_id  head_token_id  dependency_length  \
# 0      doc1-s0             5         1              3               -2.0
# 1      doc1-s0             5         2              3               -1.0
# 2      doc1-s0             5         3              0                0.0
# 3      doc1-s0             5         4              3                1.0
# 4      doc1-s0             5         5              3                2.0
# 5     doc11-s0             5         1              0                0.0
# 6     doc11-s0             5         2              1                1.0
# 7     doc11-s0             5         3              4               -1.0
# 8     doc11-s0             5         4              1                3.0
# 9     doc11-s0             5         5              4                1.0
# 10    doc12-s0             5         1              5               -4.0
# 11    doc12-s0             5         2              5               -3.0
# ...

# %%
df.shape
# Out:
# (897500, 28)

# %%
df[df.doc_id == "doc4-s30"]
# Out:
#        Unnamed: 0  Unnamed: 0.1    doc_id  paragraph_id  sentence_id  \
# 29959          49            50  doc4-s30             1            1
# 29960          50            51  doc4-s30             1            1
# 29961          51            52  doc4-s30             1            1
# 29962          52            53  doc4-s30             1            1
# 29963          53            54  doc4-s30             1            1
# 29964          54            55  doc4-s30             1            1
# 29965          55            56  doc4-s30             1            1
# 29966          56            57  doc4-s30             1            1
# 29967          57            58  doc4-s30             1            1
# 29968          58            59  doc4-s30             1            1
# 29969          59            60  doc4-s30             1            1
# 29970          60            61  doc4-s30             1            1
# 29971          61            62  doc4-s30             1            1
# ...
