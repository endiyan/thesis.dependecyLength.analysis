# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw.csv")

# %%
# create unique id for each sentence

df['sentence_uniq_id'] = df['doc_id'].apply(str) + df['paragraph_id'].apply(str) + df['sentence_id'].apply(str)

# %%
# identify last PUNCT on every sentence

df["end_of_sentence"] = False
df["token_length"] = 0

current_id = df.loc[0,'sentence_uniq_id']
for index, row in df.iterrows():
    if row["sentence_uniq_id"] != current_id:
        current_id = row["sentence_uniq_id"]
        df.at[index-1, "end_of_sentence"] = True
        df.at[index-1, "token_length"] = df.at[index-1, "token_id"] - 1

# %%
# calculate token_length for each sentence

df["token_length"] = 0

current_id = df.loc[0,'sentence_uniq_id']
for index, row in df.iterrows():
    if row["sentence_uniq_id"] != current_id:
        current_id = row["sentence_uniq_id"]
        df.at[index-1, "token_length"] = df.at[index-1, "token_id"] - 1

# %%
# delete every PUNCT at the end of every sentence
#df = df.drop(df[df.end_of_sentence].index)

# %%
# calculate dependency_length for each token

df['dependency_length'] = df['token_id'] - df['head_token_id']

# %%
# calculate jumlah dependency_lenght for each sentence

current_id = df.loc[0,'sentence_uniq_id']
sum_dependency_length = 0
df["sum_dependency_length"] = np.NaN

for index, row in df.iterrows():
    if row["sentence_uniq_id"] == current_id:
        if not row.end_of_sentence: # not counting the dependency_length of last PUNCT
            sum_dependency_length += abs(row["dependency_length"])
    else:
        df.at[index-1, "sum_dependency_length"] = sum_dependency_length
        sum_dependency_length = 0
        current_id = row["sentence_uniq_id"]

# %%
# tau average jarak dependensi (pake rumus)
df
# Out:
#      Unnamed: 0 doc_id  paragraph_id  sentence_id  \
# 0             1   doc1             1            1
# 1             2   doc1             1            1
# 2             3   doc1             1            1
# 3             4   doc1             1            1
# 4             5   doc1             1            1
# 5             6   doc1             1            2
# 6             7   doc1             1            2
# 7             8   doc1             1            2
# 8             9   doc1             1            2
# 9            10   doc1             1            2
# 10           11   doc1             1            2
# 11           12   doc1             1            2
# 12           13   doc1             1            2
# 13           14   doc1             1            2
# 14           15   doc1             1            2
# 15           16   doc1             1            2
# 16           17   doc2             1            1
# 17           18   doc2             1            1
# 18           19   doc2             1            1
# 19           20   doc2             1            1
# 20           21   doc2             1            1
# 21           22   doc2             1            1
# 22           23   doc2             1            1
# 23           24   doc2             1            1
# 24           25   doc2             1            1
# 25           26   doc2             1            1
# 26           27   doc2             1            1
# 27           28   doc2             1            1
# 28           29   doc2             1            1
# 29           30   doc2             1            2
# ..          ...    ...           ...          ...
# 704         705  doc42             1            2
# 705         706  doc42             1            2
# 706         707  doc42             1            2
# 707         708  doc42             1            2
# 708         709  doc42             1            3
# 709         710  doc42             1            3
# 710         711  doc42             1            3
# 711         712  doc42             1            3
# 712         713  doc42             1            3
# 713         714  doc42             1            4
# 714         715  doc42             1            4
# 715         716  doc42             1            4
# 716         717  doc42             1            4
# 717         718  doc42             1            4
# 718         719  doc42             1            4
# 719         720  doc42             1            4
# 720         721  doc42             1            4
# 721         722  doc42             1            4
# 722         723  doc42             1            4
# 723         724  doc42             1            4
# 724         725  doc42             1            4
# 725         726  doc42             1            4
# 726         727  doc43             1            1
# 727         728  doc43             1            1
# 728         729  doc43             1            1
# 729         730  doc43             1            1
# 730         731  doc43             1            1
# 731         732  doc43             1            1
# 732         733  doc44             1            1
# 733         734  doc44             1            1
#
#                                               sentence  token_id  \
# 0                             Pak, mengganggu sedikit.         1
# 1                             Pak, mengganggu sedikit.         2
# 2                             Pak, mengganggu sedikit.         3
# 3                             Pak, mengganggu sedikit.         4
# 4                             Pak, mengganggu sedikit.         5
# 5      Kami dari RRI. Sudah lama Bapak muncul di sini?         1
# 6      Kami dari RRI. Sudah lama Bapak muncul di sini?         2
# 7      Kami dari RRI. Sudah lama Bapak muncul di sini?         3
# 8      Kami dari RRI. Sudah lama Bapak muncul di sini?         4
# 9      Kami dari RRI. Sudah lama Bapak muncul di sini?         5
# 10     Kami dari RRI. Sudah lama Bapak muncul di sini?         6
# 11     Kami dari RRI. Sudah lama Bapak muncul di sini?         7
# 12     Kami dari RRI. Sudah lama Bapak muncul di sini?         8
# 13     Kami dari RRI. Sudah lama Bapak muncul di sini?         9
# 14     Kami dari RRI. Sudah lama Bapak muncul di sini?        10
# 15     Kami dari RRI. Sudah lama Bapak muncul di sini?        11
# 16   Sudah lama juga, karena saya sudah di sini sej...         1
# 17   Sudah lama juga, karena saya sudah di sini sej...         2
# 18   Sudah lama juga, karena saya sudah di sini sej...         3
# 19   Sudah lama juga, karena saya sudah di sini sej...         4
# 20   Sudah lama juga, karena saya sudah di sini sej...         5
# 21   Sudah lama juga, karena saya sudah di sini sej...         6
# 22   Sudah lama juga, karena saya sudah di sini sej...         7
# 23   Sudah lama juga, karena saya sudah di sini sej...         8
# 24   Sudah lama juga, karena saya sudah di sini sej...         9
# 25   Sudah lama juga, karena saya sudah di sini sej...        10
# 26   Sudah lama juga, karena saya sudah di sini sej...        11
# 27   Sudah lama juga, karena saya sudah di sini sej...        12
# 28   Sudah lama juga, karena saya sudah di sini sej...        13
# 29                              Jadi, cukup lama juga.         1
# ..                                                 ...       ...
# 704  Tapi saya syukur saya sudah bisa menghidupi ke...         7
# 705  Tapi saya syukur saya sudah bisa menghidupi ke...         8
# 706  Tapi saya syukur saya sudah bisa menghidupi ke...         9
# 707  Tapi saya syukur saya sudah bisa menghidupi ke...        10
# 708               Sudah bisa menabung sedikit-sedikit.         1
# 709               Sudah bisa menabung sedikit-sedikit.         2
# 710               Sudah bisa menabung sedikit-sedikit.         3
# 711               Sudah bisa menabung sedikit-sedikit.         4
# 712               Sudah bisa menabung sedikit-sedikit.         5
# 713  Walaupun tidak banyak, tapi saya bersyukur kar...         1
# 714  Walaupun tidak banyak, tapi saya bersyukur kar...         2
# 715  Walaupun tidak banyak, tapi saya bersyukur kar...         3
# 716  Walaupun tidak banyak, tapi saya bersyukur kar...         4
# 717  Walaupun tidak banyak, tapi saya bersyukur kar...         5
# 718  Walaupun tidak banyak, tapi saya bersyukur kar...         6
# 719  Walaupun tidak banyak, tapi saya bersyukur kar...         7
# 720  Walaupun tidak banyak, tapi saya bersyukur kar...         8
# 721  Walaupun tidak banyak, tapi saya bersyukur kar...         9
# 722  Walaupun tidak banyak, tapi saya bersyukur kar...        10
# 723  Walaupun tidak banyak, tapi saya bersyukur kar...        11
# 724  Walaupun tidak banyak, tapi saya bersyukur kar...        12
# 725  Walaupun tidak banyak, tapi saya bersyukur kar...        13
# 726                           Namanya tadi siapa, Pak?         1
# 727                           Namanya tadi siapa, Pak?         2
# 728                           Namanya tadi siapa, Pak?         3
# 729                           Namanya tadi siapa, Pak?         4
# 730                           Namanya tadi siapa, Pak?         5
# 731                           Namanya tadi siapa, Pak?         6
# 732                                              Amir.         1
# 733                                              Amir.         2
#
#                token  lemma   upos  xpos           ...                dep_rel  \
# 0                Pak    NaN  PROPN   NaN           ...                  nsubj
# 1                  ,    NaN  PUNCT   NaN           ...                  punct
# 2         mengganggu    NaN   VERB   NaN           ...                   root
# 3            sedikit    NaN    ADV   NaN           ...                 advmod
# 4                  .    NaN  PUNCT   NaN           ...                  punct
# 5               Kami    NaN  PROPN   NaN           ...                  nsubj
# 6               dari    NaN    ADP   NaN           ...                   case
# 7                RRI    NaN  PROPN   NaN           ...                   nmod
# 8                  .    NaN  PUNCT   NaN           ...                  punct
# 9              Sudah    NaN  PROPN   NaN           ...                   flat
# 10              lama    NaN    ADJ   NaN           ...                   amod
# 11             Bapak    NaN  PROPN   NaN           ...                   flat
# 12            muncul    NaN   VERB   NaN           ...                   root
# 13                di    NaN    ADP   NaN           ...                   case
# 14              sini    NaN   NOUN   NaN           ...                    obl
# 15                 ?    NaN  PUNCT   NaN           ...                  punct
# 16             Sudah    NaN    ADV   NaN           ...                 advmod
# 17              lama    NaN    ADJ   NaN           ...                   root
# 18              juga    NaN    ADV   NaN           ...                 advmod
# 19                 ,    NaN  PUNCT   NaN           ...                  punct
# 20            karena    NaN  SCONJ   NaN           ...                   mark
# 21              saya    NaN   PRON   NaN           ...             nsubj:pass
# 22             sudah    NaN    ADV   NaN           ...                 advmod
# 23                di    NaN    ADP   NaN           ...                   case
# 24              sini    NaN   NOUN   NaN           ...                    obl
# 25             sejak    NaN    ADP   NaN           ...                   case
# 26               ini    NaN    DET   NaN           ...                    det
# 27        diresmikan    NaN   VERB   NaN           ...                   conj
# 28                 .    NaN  PUNCT   NaN           ...                  punct
# 29              Jadi    NaN    ADV   NaN           ...                 advmod
# ..               ...    ...    ...   ...           ...                    ...
# 704       menghidupi    NaN   VERB   NaN           ...                  advcl
# 705         keluarga    NaN   NOUN   NaN           ...                    obj
# 706             saya    NaN   PRON   NaN           ...                    det
# 707                .    NaN  PUNCT   NaN           ...                  punct
# 708            Sudah    NaN    ADV   NaN           ...                 advmod
# 709             bisa    NaN    ADV   NaN           ...                 advmod
# 710         menabung    NaN   VERB   NaN           ...                   root
# 711  sedikit-sedikit    NaN    ADV   NaN           ...                 advmod
# 712                .    NaN  PUNCT   NaN           ...                  punct
# 713         Walaupun    NaN  SCONJ   NaN           ...                   mark
# 714            tidak    NaN   PART   NaN           ...                 advmod
# 715           banyak    NaN    ADV   NaN           ...                 advmod
# 716                ,    NaN  PUNCT   NaN           ...                  punct
# 717             tapi    NaN  SCONJ   NaN           ...                   mark
# 718             saya    NaN   PRON   NaN           ...             nsubj:pass
# 719        bersyukur    NaN   VERB   NaN           ...                   root
# 720           karena    NaN  SCONJ   NaN           ...                   mark
# 721          bantuan    NaN   NOUN   NaN           ...                    obl
# 722             dari    NaN    ADP   NaN           ...                   case
# 723       pemerintah    NaN   NOUN   NaN           ...                   nmod
# 724              ini    NaN    DET   NaN           ...                    det
# 725                .    NaN  PUNCT   NaN           ...                  punct
# 726          Namanya    NaN   NOUN   NaN           ...                   root
# 727             tadi    NaN   NOUN   NaN           ...               compound
# 728            siapa    NaN   NOUN   NaN           ...               compound
# 729                ,    NaN  PUNCT   NaN           ...                  punct
# 730              Pak    NaN  PROPN   NaN           ...                  appos
# 731                ?    NaN  PUNCT   NaN           ...                  punct
# 732             Amir    NaN  PROPN   NaN           ...                   root
# 733                .    NaN  PUNCT   NaN           ...                  punct
#
#      deps            misc  sentence_uniq_id end_of_sentence token_length  \
# 0     NaN   SpaceAfter=No            doc111           False            0
# 1     NaN             NaN            doc111           False            0
# 2     NaN             NaN            doc111           False            0
# 3     NaN   SpaceAfter=No            doc111           False            0
# 4     NaN             NaN            doc111            True            4
# 5     NaN             NaN            doc112           False            0
# 6     NaN             NaN            doc112           False            0
# 7     NaN   SpaceAfter=No            doc112           False            0
# 8     NaN             NaN            doc112           False            0
# 9     NaN             NaN            doc112           False            0
# 10    NaN             NaN            doc112           False            0
# 11    NaN             NaN            doc112           False            0
# 12    NaN             NaN            doc112           False            0
# 13    NaN             NaN            doc112           False            0
# 14    NaN   SpaceAfter=No            doc112           False            0
# 15    NaN  SpacesAfter=\n            doc112            True           10
# 16    NaN             NaN            doc211           False            0
# 17    NaN             NaN            doc211           False            0
# 18    NaN   SpaceAfter=No            doc211           False            0
# 19    NaN             NaN            doc211           False            0
# 20    NaN             NaN            doc211           False            0
# 21    NaN             NaN            doc211           False            0
# 22    NaN             NaN            doc211           False            0
# 23    NaN             NaN            doc211           False            0
# 24    NaN             NaN            doc211           False            0
# 25    NaN             NaN            doc211           False            0
# 26    NaN             NaN            doc211           False            0
# 27    NaN   SpaceAfter=No            doc211           False            0
# 28    NaN             NaN            doc211            True           12
# 29    NaN   SpaceAfter=No            doc212           False            0
# ..    ...             ...               ...             ...          ...
# 704   NaN             NaN           doc4212           False            0
# 705   NaN             NaN           doc4212           False            0
# 706   NaN   SpaceAfter=No           doc4212           False            0
# 707   NaN             NaN           doc4212            True            9
# 708   NaN             NaN           doc4213           False            0
# 709   NaN             NaN           doc4213           False            0
# 710   NaN             NaN           doc4213           False            0
# 711   NaN   SpaceAfter=No           doc4213           False            0
# 712   NaN             NaN           doc4213            True            4
# 713   NaN             NaN           doc4214           False            0
# 714   NaN             NaN           doc4214           False            0
# 715   NaN   SpaceAfter=No           doc4214           False            0
# 716   NaN             NaN           doc4214           False            0
# 717   NaN             NaN           doc4214           False            0
# 718   NaN             NaN           doc4214           False            0
# 719   NaN             NaN           doc4214           False            0
# 720   NaN             NaN           doc4214           False            0
# 721   NaN             NaN           doc4214           False            0
# 722   NaN             NaN           doc4214           False            0
# 723   NaN             NaN           doc4214           False            0
# 724   NaN   SpaceAfter=No           doc4214           False            0
# 725   NaN  SpacesAfter=\n           doc4214            True           12
# 726   NaN             NaN           doc4311           False            0
# 727   NaN             NaN           doc4311           False            0
# 728   NaN   SpaceAfter=No           doc4311           False            0
# 729   NaN             NaN           doc4311           False            0
# 730   NaN   SpaceAfter=No           doc4311           False            0
# 731   NaN  SpacesAfter=\n           doc4311            True            5
# 732   NaN   SpaceAfter=No           doc4411           False            0
# 733   NaN  SpacesAfter=\n           doc4411           False            0
#
#      dependency_length  sum_dependency_length  avg_positive_dependency  \
# 0                   -2                    NaN                     None
# 1                    1                    NaN                     None
# 2                    3                    NaN                     None
# 3                    1                    NaN                     None
# 4                    2                    7.0                     1.75
# 5                   -7                    NaN                     None
# 6                   -1                    NaN                     None
# 7                    2                    NaN                     None
# 8                    3                    NaN                     None
# 9                    4                    NaN                     None
# 10                   5                    NaN                     None
# 11                   6                    NaN                     None
# 12                   8                    NaN                     None
# 13                  -1                    NaN                     None
# 14                   2                    NaN                     None
# 15                   3                   32.0                  3.33333
# 16                  -1                    NaN                     None
# 17                   2                    NaN                     None
# 18                   1                    NaN                     None
# 19                  -8                    NaN                     None
# 20                  -7                    NaN                     None
# 21                  -6                    NaN                     None
# 22                  -2                    NaN                     None
# 23                  -1                    NaN                     None
# 24                  -3                    NaN                     None
# 25                   1                    NaN                     None
# 26                   2                    NaN                     None
# 27                  10                    NaN                     None
# 28                   1                   43.0                  3.16667
# 29                  -3                    NaN                     None
# ..                 ...                    ...                      ...
# 704                  4                    NaN                     None
# 705                  1                    NaN                     None
# 706                  1                    NaN                     None
# 707                  7                   14.0                  3.15012
# 708                 -2                    NaN                     None
# 709                 -1                    NaN                     None
# 710                  3                    NaN                     None
# 711                  1                    NaN                     None
# 712                  2                    5.0                  3.14183
# 713                 -2                    NaN                     None
# 714                 -1                    NaN                     None
# 715                 -4                    NaN                     None
# 716                  1                    NaN                     None
# 717                 -2                    NaN                     None
# 718                 -1                    NaN                     None
# 719                  7                    NaN                     None
# 720                 -1                    NaN                     None
# 721                  2                    NaN                     None
# 722                 -1                    NaN                     None
# 723                  2                    NaN                     None
# 724                  1                    NaN                     None
# 725                  6                   23.0                  3.14218
# 726                  1                    NaN                     None
# 727                  1                    NaN                     None
# 728                  2                    NaN                     None
# 729                  3                    NaN                     None
# 730                  4                    NaN                     None
# 731                  5                   10.0                  3.14052
# 732                  1                    NaN                     None
# 733                  1                    NaN                     None
#
#      avg_negative_dependency
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                          2
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
# 10                      None
# 11                      None
# 12                      None
# 13                      None
# 14                      None
# 15                   1.33333
# 16                      None
# 17                      None
# 18                      None
# 19                      None
# 20                      None
# 21                      None
# 22                      None
# 23                      None
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                   3.44444
# 29                      None
# ..                       ...
# 704                     None
# 705                     None
# 706                     None
# 707                  1.89352
# 708                     None
# 709                     None
# 710                     None
# 711                     None
# 712                   1.8894
# 713                     None
# 714                     None
# 715                     None
# 716                     None
# 717                     None
# 718                     None
# 719                     None
# 720                     None
# 721                     None
# 722                     None
# 723                     None
# 724                     None
# 725                  1.88341
# 726                     None
# 727                     None
# 728                     None
# 729                     None
# 730                     None
# 731                  1.88341
# 732                     None
# 733                     None
#
# [734 rows x 22 columns]

# %% [raw]
# # average maju dan average mundur per kalimat
#
# # initialize value for average positive and negative value for each sentence
# df["avg_positive_dependency"] = None
# df["avg_negative_dependency"] = None
#
# # initialize value for count and sum
# list_positive_dependency = []
# list_negative_dependency = []
#
# # init current_sentence_id with first sentence_uniq_id
# current_sentence_id = df.loc[0,'sentence_uniq_id']
#
# for index, row in df.iterrows():
#     if row["sentence_uniq_id"] == current_sentence_id:
#         # add element to list negative dependency
#         if row.dependency_length < 0:
#             list_negative_dependency.append(row.dependency_length)
#         else:
#             list_positive_dependency.append(row.dependency_length)
#     else:
#         # write averera dependency on data frame
#         df.at[index-1, "avg_positive_dependency"] = np.mean(list_positive_dependency)
#         df.at[index-1, "avg_negative_dependency"] = np.abs(np.mean(list_negative_dependency))
#         current_sentence_id = row["sentence_uniq_id"]

# %% [raw]
# len(df.loc[df.sum_dependency_length.notnull(), ["token_length","sum_dependency_length"]])
# len(df.sum_dependency_length.notnull())
# df.sentence_uniq_id.value_counts()

# %%
import plotly.plotly as py
import cufflinks as cf

# %%
df.loc[df.sum_dependency_length.notnull(), ["sentence", "token_length","sum_dependency_length", "avg_positive_dependency", "avg_negative_dependency"]]
# Out:
#                                               sentence  token_length  \
# 4                             Pak, mengganggu sedikit.             4
# 15     Kami dari RRI. Sudah lama Bapak muncul di sini?            10
# 28   Sudah lama juga, karena saya sudah di sini sej...            12
# 34                              Jadi, cukup lama juga.             5
# 40                            Apa yang dijual di sini?             5
# 59   Kita lihat ini di depan ada minuman Coca-Cola,...            18
# 67       Penghasilan setiap hari berapa biasanya, Pak?             7
# 71                         Penghasilannya tidak tentu.             3
# 83   Kalau lagi ada keramaian, mungkin kita bisa da...            11
# 96   Kalau hari-hari biasa begini, kadang 200 atau ...            12
# 102                         Biasa yang ramai hari apa?             5
# 120  Kalau pas lagi ada acara di anjungan ini, ada ...            17
# 125                          Seperti ketika ada artis.             4
# 135  Dari jam berapa sampai jam berapa berjualan di...             9
# 143             Kalau hari biasa, kita berjualan sore.             7
# 149                Kadang teman-teman datang jam tiga.             5
# 159    Kalau hari Minggu, kadang dia bermalam di sini.             9
# 163                                 Sampai jam berapa?             3
# 168                           Sampai jam sepuluh pagi.             4
# 172                                   Itu sudah bubar.             3
# 187  Tapi kalau ada acara atau event, buka di lapan...            14
# 200  Kadang ada juga yang menetap di sini sambil me...            12
# 204                  Mengenai kebersihannya bagaimana?             3
# 214  Mengenai kebersihan, kita sudah pernah rapatka...             9
# 222  Kita betul-betul menjaga betul kebersihan di s...             7
# 226                              Itu tanpa terkecuali.             3
# 237  Kita kerjasama dengan instansi seperti pamong ...            10
# 249  Kalau mengenai kebersihan, kita betul betul-be...            11
# 255             Bagaimana cara menjaga kebersihan itu?             5
# 289  Misalnya ada pengunjung buang sampah sembarang...            33
# ..                                                 ...           ...
# 490                                  Ada berapa orang?             3
# 497                     Ada tiga tim di Pantai Losari.             6
# 507  Ada bendahara, ada ketua kebersihan, ada penga...             9
# 520  Sampah sekecil apa pun, seperti puntung rokok,...            12
# 526                     Berapa jumlah penjual di sini?             5
# 531                             152 kalau tidak salah.             4
# 538                    Itu setiap hari dagang di sini?             6
# 540                                               Iya.             1
# 547      Tapi kadang-kadang juga tidak semuanya aktif.             6
# 554                 Kadang ada juga yang tidak datang.             6
# 567  Tapi kalau biasanya ada event-event terbuka, i...            12
# 574                    Dari luar ada yang datang juga.             6
# 591  Nah, itulah yang bisa bikin kendala, karena or...            16
# 605  Kalau kita orang di sini sudah jaga kebersihan...            13
# 609                                     Jadi, percuma.             3
# 615              Kita sudah bersihkan apa-apa sendiri.             5
# 624          Maaf, Pak. Anaknya sudah berapa sekarang?             8
# 630                        Istri pertama dulu ada dua.             5
# 637                Kalau ini istri sekarang belum ada.             6
# 647  Apakah Bapak sudah merasa nyaman untuk berdaga...             9
# 649                                     Alhamdulillah.             1
# 660  Saya merasa nyaman karena saya sudah bisa usah...            10
# 677  Tidak lagi seperti dulu saya bawak becak, itu ...            16
# 686  Apa saja yang Bapak sudah rasakan dengan berju...             8
# 694        Mungkin sudah bangun rumah atau beli motor?             7
# 697                                         Belum ada.             2
# 707  Tapi saya syukur saya sudah bisa menghidupi ke...             9
# 712               Sudah bisa menabung sedikit-sedikit.             4
# 725  Walaupun tidak banyak, tapi saya bersyukur kar...            12
# 731                           Namanya tadi siapa, Pak?             5
#
#      sum_dependency_length avg_positive_dependency avg_negative_dependency
# 4                      7.0                    1.75                       2
# 15                    32.0                 3.33333                 1.33333
# 28                    43.0                 3.16667                 3.44444
# 34                     7.0                 2.95455                     3.2
# 40                     6.0                    2.96                 2.83333
# 59                    49.0                 3.46154                  2.4375
# 67                    17.0                 3.51111                 2.35294
# 71                     4.0                 3.44681                 2.27778
# 83                    28.0                 3.39623                 2.34783
# 96                    34.0                 3.34426                 2.44444
# 102                    5.0                 3.27692                 2.39286
# 120                   49.0                 3.37838                 2.41667
# 125                    5.0                 3.32468                 2.37838
# 135                   21.0                 3.28916                   2.375
# 143                   15.0                 3.25287                 2.37209
# 149                    6.0                 3.17391                 2.37209
# 159                   21.0                 3.16495                  2.3617
# 163                    3.0                    3.12                  2.3617
# 168                    5.0                 3.09709                 2.33333
# 172                    4.0                 3.07619                 2.30612
# 187                   35.0                 3.19469                 2.21818
# 200                   22.0                 3.22314                 2.13559
# 204                    3.0                 3.18548                 2.13559
# 214                   25.0                 3.20472                 2.18462
# 222                   10.0                 3.18182                 2.14925
# 226                    3.0                 3.17164                 2.13235
# 237                   13.0                 3.14894                 2.08451
# 249                   26.0                 3.14966                 2.09211
# 255                    6.0                 3.11921                 2.07792
# 289                  111.0                 3.14535                 2.35955
# ..                     ...                     ...                     ...
# 490                    3.0                 3.12203                 2.03497
# 497                    7.0                 3.11706                 2.02069
# 507                   22.0                 3.12662                 2.02069
# 520                   46.0                 3.16981                  2.0068
# 526                    7.0                 3.16149                       2
# 531                    7.0                 3.15741                 1.99333
# 538                    9.0                 3.15596                 1.97386
# 540                    0.0                 3.14939                 1.97386
# 547                   12.0                 3.14502                 1.97436
# 554                   10.0                 3.14328                 1.96835
# 567                   24.0                 3.15249                 1.95122
# 574                   11.0                 3.14203                 1.95181
# 591                   35.0                 3.16573                 1.92982
# 605                   29.0                  3.1768                 1.92697
# 609                    4.0                 3.17033                 1.92179
# 615                    6.0                 3.15761                 1.91667
# 624                   19.0                 3.15282                 1.91803
# 630                    7.0                 3.14058                 1.91304
# 637                   13.0                 3.14248                 1.90957
# 647                   15.0                 3.14323                 1.89583
# 649                    0.0                 3.13766                 1.89583
# 660                   21.0                 3.14066                 1.90816
# 677                   43.0                 3.16414                 1.92271
# 686                   13.0                  3.1725                 1.90995
# 694                    9.0                 3.16296                 1.90141
# 697                    2.0                 3.15479                 1.90141
# 707                   14.0                 3.15012                 1.89352
# 712                    5.0                 3.14183                  1.8894
# 725                   23.0                 3.14218                 1.88341
# 731                   10.0                 3.14052                 1.88341
#
# [83 rows x 5 columns]

# %% [raw]
# #df.loc[df.sum_dependency_length.notnull(), ["token_length","sum_dependency_length"]].plot(kind='bar')

# %%
from plotly.graph_objs import *

py.iplot({
    'data': [
        Bar(**{
            'x': df.loc[df.sum_dependency_length.notnull(),"token_length"], 
            'y': df.loc[df.sum_dependency_length.notnull(),"sum_dependency_length"],
            'name' : 'Sum Dependency Length',
            'type': 'bar'
        })
    ],
    'layout': Layout(**{
        'title': 'Sum Dependency Length'
    })
})
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~endiyan/32.embed" height="525px" width="100%"></iframe>

# %%
from plotly.graph_objs import *

py.iplot({
    'data': [
        Bar(**{
            'x': df.loc[df.sum_dependency_length.notnull(),"token_length"], 
            'y': df.loc[df.sum_dependency_length.notnull(),"avg_positive_dependency"],
            'name' : 'Avg Positive Dependency',
            'type': 'bar'
        }),
        Bar(**{
            'x': df.loc[df.sum_dependency_length.notnull(),"token_length"], 
            'y': df.loc[df.sum_dependency_length.notnull(),"avg_negative_dependency"],
            'name' : 'Avg Negative Dependency',
            'type': 'bar'
        })
    ],
    'layout': Layout(**{
        'title': 'Average Positive and Negative Dependency Length'
    })
})
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~endiyan/34.embed" height="525px" width="100%"></iframe>

# %%
#liat average dari average jarak dependensi di masing2 cluster
#liat average maju dan mundur di masing masing cluster
#bikin histogram 8 dan 9
